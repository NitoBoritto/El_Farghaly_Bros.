# %% [markdown]
# # Loading dataset from Azure database

# %%
import pandas as pd
from pathlib import Path
import sys

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.database.extract import load_db_table_to_dataframe
from database import get_db_engine 

df_bank = load_db_table_to_dataframe("Transformed.Bank", get_db_engine())
df_bank.head()
# Out:
# Database engine created successfully.
# Successfully loaded 'Transformed.Bank' with shape (41188, 22)
#    age        job  marital       education  default housing loan    contact  \
# 0   56  housemaid  married  primary school       no      no   no  telephone
# 1   57   services  married     high school  unknown      no   no  telephone
# 2   37   services  married     high school       no     yes   no  telephone
# 3   40      admin  married   middle school       no      no   no  telephone
# 4   56   services  married     high school       no      no  yes  telephone
#
#    month  day_of_week  ...  pdays  previous     poutcome  emp.var.rate  \
# 0      5            1  ...    999         0  nonexistent           1.1
# 1      5            1  ...    999         0  nonexistent           1.1
# 2      5            1  ...    999         0  nonexistent           1.1
# 3      5            1  ...    999         0  nonexistent           1.1
# 4      5            1  ...    999         0  nonexistent           1.1
#
#   cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y    pdays_group
# 0         93.994          -36.4      4.857       5191.0  no  not contacted
# 1         93.994          -36.4      4.857       5191.0  no  not contacted
# 2         93.994          -36.4      4.857       5191.0  no  not contacted
# 3         93.994          -36.4      4.857       5191.0  no  not contacted
# 4         93.994          -36.4      4.857       5191.0  no  not contacted
#
# [5 rows x 22 columns]

# %%
# Save DataFrame to CSV
output_path = Path(f"{project_root}/data/processed/transformed_bank.csv")
output_path.parent.mkdir(parents=True, exist_ok=True)
df_bank.to_csv(output_path, index=False, encoding="utf-8-sig")
print(f"Saved to: {output_path.resolve()}")
# Out:
# Saved to: D:\ML Projects\El_Farghaly_Bros\data\processed\transformed_bank.csv
