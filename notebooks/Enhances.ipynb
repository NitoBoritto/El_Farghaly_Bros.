# %%
import pandas as pd
from pathlib import Path
import sys
project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.database.extract import load_db_table_to_dataframe
from database import get_db_engine 

df_bank = load_db_table_to_dataframe("Transformed.Bank", get_db_engine())
df_bank.head()
# Out:
# Database engine created successfully.
# Error loading table 'Transformed.Bank': (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect)')
# (Background on this error at: https://sqlalche.me/e/20/rvf5)
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3317, in Engine.raw_connection(self)
#    3296 """Return a "raw" DBAPI connection from the connection pool.
#    3297
#    3298 The returned object is a proxied version of the DBAPI
#    (...)   3315
#    3316 """
# -> 3317 return self.pool.connect()
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
#     443 The connection is instrumented such that when its
#    (...)    446
#     447 """
# --> 448 return _ConnectionFairy._checkout(self)
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\pool\base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1271 if not fairy:
# -> 1272     fairy = _ConnectionRecord.checkout(pool)
#    1274     if threadconns is not None:
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:175, in QueuePool._do_get(self)
#     174 try:
# --> 175     return self._create_connection()
#     176 except:
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\pool\base.py:389, in Pool._create_connection(self)
#     387 """Called by subclasses to create a new ConnectionRecord."""
# --> 389 return _ConnectionRecord(self)
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\engine\create.py:667, in create_engine.<locals>.connect(connection_record)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\engine\default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# InterfaceError: ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect)')
#
# The above exception was the direct cause of the following exception:
#
# InterfaceError                            Traceback (most recent call last)
# Cell In[3], line 11
#       7
#       8 from src.database.extract import load_db_table_to_dataframe
#       9 from database import get_db_engine
#      10
# ---> 11 df_bank = load_db_table_to_dataframe("Transformed.Bank", get_db_engine())
#      12 df_bank.head()
#
# File f:\Abdallah Work\Abdallah College\Farghaly\src\database\extract.py:17, in load_db_table_to_dataframe(table_name, engine)
#       5 """
#       6 Loads a specified table from the database into a pandas DataFrame.
#       7
#    (...)     14 table_name
#      15 """
#      16 try:
# ---> 17     df = pd.read_sql(f'SELECT * FROM {table_name}', con=engine)
#      18     print(f"Successfully loaded '{table_name}' with shape {df.shape}")
#      19     return df
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\pandas\io\sql.py:706, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     703     dtype_backend = "numpy"  # type: ignore[assignment]
#     704 assert dtype_backend is not lib.no_default
# --> 706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
#     708         return pandas_sql.read_query(
#     709             sql,
#     710             index_col=index_col,
#    (...)    716             dtype=dtype,
#     717         )
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\pandas\io\sql.py:908, in pandasSQL_builder(con, schema, need_transaction)
#     905     raise ImportError("Using URI string without sqlalchemy installed.")
#     907 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 908     return SQLDatabase(con, schema, need_transaction)
#     910 adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#     911 if adbc and isinstance(con, adbc.Connection):
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\pandas\io\sql.py:1648, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1646     self.exit_stack.callback(con.dispose)
#    1647 if isinstance(con, Engine):
# -> 1648     con = self.exit_stack.enter_context(con.connect())
#    1649 if need_transaction and not con.in_transaction():
#    1650     self.exit_stack.enter_context(con.begin())
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3293, in Engine.connect(self)
#    3270 def connect(self) -> Connection:
#    3271     """Return a new :class:`_engine.Connection` object.
#    3272
#    3273     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)   3290
#    3291     """
# -> 3293     return self._connection_cls(self)
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
# --> 145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#     148         raise
#     149 else:
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2448, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2446 elif should_wrap:
#    2447     assert sqlalchemy_exception is not None
# -> 2448     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2449 else:
#    2450     assert exc_info[1] is not None
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     141 if connection is None:
#     142     try:
# --> 143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
#     145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3317, in Engine.raw_connection(self)
#    3295 def raw_connection(self) -> PoolProxiedConnection:
#    3296     """Return a "raw" DBAPI connection from the connection pool.
#    3297
#    3298     The returned object is a proxied version of the DBAPI
#    (...)   3315
#    3316     """
# -> 3317     return self.pool.connect()
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     440 def connect(self) -> PoolProxiedConnection:
#     441     """Return a DBAPI connection from the pool.
#     442
#     443     The connection is instrumented such that when its
#    (...)    446
#     447     """
# --> 448     return _ConnectionFairy._checkout(self)
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\pool\base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1264 @classmethod
#    1265 def _checkout(
#    1266     cls,
#    (...)   1269     fairy: Optional[_ConnectionFairy] = None,
#    1270 ) -> _ConnectionFairy:
#    1271     if not fairy:
# -> 1272         fairy = _ConnectionRecord.checkout(pool)
#    1274         if threadconns is not None:
#    1275             threadconns.current = weakref.ref(fairy)
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175     return self._create_connection()
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#     179     raise
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     119     assert exc_value is not None
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#     123     self._exc_info = None  # remove potential circular references
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:175, in QueuePool._do_get(self)
#     173 if self._inc_overflow():
#     174     try:
# --> 175         return self._create_connection()
#     176     except:
#     177         with util.safe_reraise():
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\pool\base.py:389, in Pool._create_connection(self)
#     386 def _create_connection(self) -> ConnectionPoolEntry:
#     387     """Called by subclasses to create a new ConnectionRecord."""
# --> 389     return _ConnectionRecord(self)
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     119     assert exc_value is not None
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#     123     self._exc_info = None  # remove potential circular references
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\engine\create.py:667, in create_engine.<locals>.connect(connection_record)
#     665     return dialect.connect(*mutable_cargs, **mutable_cparams)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File f:\Abdallah Work\Abdallah College\Farghaly\.venv\Lib\site-packages\sqlalchemy\engine\default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect)')
# (Background on this error at: https://sqlalche.me/e/20/rvf5)
